# %%
from google.colab import drive 
drive.mount('/content/drive')

import shutil, glob, os

new_folder = "final_batch_3"
assert type(new_folder) is str, "Please set new folder name first"

os.mkdir(f'/content/drive/Shareddrives/Tomato/{new_folder}')

for f in glob.glob('/content/drive/Shareddrives/Tomato/template/*.py'):
  shutil.copy(f,f'/content/drive/Shareddrives/Tomato/{new_folder}')
for f in glob.glob('/content/drive/Shareddrives/Tomato/template/*.ipynb'):
  shutil.copy(f,f'/content/drive/Shareddrives/Tomato/{new_folder}')
for f in glob.glob('/content/drive/Shareddrives/Tomato/template/*.h5'):
  shutil.copy(f,f'/content/drive/Shareddrives/Tomato/{new_folder}')
for f in glob.glob('/content/drive/Shareddrives/Tomato/template/*.csv'):
  shutil.copy(f,f'/content/drive/Shareddrives/Tomato/{new_folder}')
# Out:
# Mounted at /content/drive
